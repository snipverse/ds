# %%
import os
os.getcwd()

# %%
import pandas as pd
mtcars = pd.read_csv(r"C:\Users\akula\mtcars (1).csv")
mtcars.head()

# %%
mtcars.tail()

# %%
mtcars.info()

# %%
mtcars.columns()

# %%
mtcars.isnull().sum()

# %%
mtcars .describe()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="cyl", data=mtcars)

# %%
mtcars.groupby(["cyl"])["mpg"].mean()

# %%
sns.boxplot(x="am", y="mpg", data=mtcars)

# %%
mtcars_reduced = mtcars.drop(['model','vs','am','gear','carb'], axis=1)
sns.heatmap(mtcars_reduced.corr(), annot=True, vmax=1)
plt.show()
